# %% [markdown]
# <a href="https://colab.research.google.com/github/arumshin-dev/python_conda_jupyter/blob/main/codeit/250901_%EC%BD%94%EB%94%A9%EC%8B%A4%EC%8A%B516_11_%EC%B0%A8%EC%9B%90%EC%B6%95%EC%86%8C(PCA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터 설명
#
# 64차원의 손글씨 데이터
#
# 사이킷런: https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_digits.html

# %%
from sklearn.datasets import load_digits                      # 손글씨 이미지 (64차원)
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
# 데이터 불러오기
X, y = load_digits(return_X_y=True)

# %%
X
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
y
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
# 데이터 표준화

X_scaled = StandardScaler().fit_transform(X)
X_scaled
# Out:
# array([[ 0.        , -0.33501649, -0.04308102, ..., -1.14664746,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649, -1.09493684, ...,  0.54856067,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649, -1.09493684, ...,  1.56568555,
#          1.6951369 , -0.19600752],
#        ...,
#        [ 0.        , -0.33501649, -0.88456568, ..., -0.12952258,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649, -0.67419451, ...,  0.8876023 ,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649,  1.00877481, ...,  0.8876023 ,
#         -0.26113572, -0.19600752]])

# %%
# PCA 전 시각화
plt.figure(figsize=(8,6))
scatter = plt.scatter(X[:,0], X[:,1], c=y,
                      cmap='tab10', alpha=0.7)
plt.xlabel('X1')
plt.ylabel('X2')
plt.colorbar(scatter, label="Digit Label")
# plt.legend(handles=scatter.legend_elements()[0], labels=range(10))
plt.show()

# %%
# PCA 전 시각화
plt.figure(figsize=(8,6))
scatter = plt.scatter(X_scaled[:,0], X_scaled[:,1], c=y,
                      cmap='tab10', alpha=0.7)
plt.xlabel('X1')
plt.ylabel('X2')
plt.colorbar()
# plt.legend(handles=scatter.legend_elements()[0], labels=range(10))
plt.show()

# %%
# 차원 축소
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
# PCA 후 시각화
plt.figure(figsize=(8,6))
scatter = plt.scatter(X_pca[:,0], X_pca[:,1], c=y,
                      cmap='tab10', alpha=0.7)
plt.xlabel('X1')
plt.ylabel('X2')
plt.colorbar(scatter, label="Digit Label")
plt.show()

# %%
# PCA 후 시각화

plt.figure(figsize=(6,4))
scatter = plt.scatter(X_pca[:,0], X_pca[:,1], c=y, cmap='tab10', alpha=0.7)
plt.xlabel('X1')
plt.ylabel('X2')
plt.colorbar(scatter, label="Digit Label")
plt.show()

# %%
# 스크리플롯

plt.figure(figsize=(12,4))
plt.plot(
        range(1, len(pca.explained_variance_ratio_)+1),        # X축
        pca.explained_variance_,                               # Y축
        marker='o', linestyle='--'
        )
