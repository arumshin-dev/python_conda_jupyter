# %%
from sklearn.model_selection import train_test_split #데이터를 트레이닝셋과 테스트 셋으로 나눠주는 함수
from sklearn.linear_model import LinearRegression # 선형회귀
from sklearn.metrics import mean_squared_error # 모델 평가할때 쓰는 평균 제곱 오차 함수

import pandas as pd

# %%
#2-16. scikit-learn 데이터 준비

# form sklearn.datasets import load_boston
# import pandas as pd

# boston_dataset = load_boston()
# print(boston_dataset.DESCR)#보스톤 데이터셋 설명서
# boston_dataset.feature_names#속성명들 받아오는것
# boston_dataset.data# 데이터 받아오는거
# X=pd.DataFrame(boston_dataset.data, boston_dataset.feature_names)# 입력변수 데이터프레임 정리 
# boston_dataset.target#목표변수
# y=pd.DataFrame(boston_dataset.target, columns=['MEDV'])# 목표변수 데이터프레임 정리 
boston_df = pd.read_csv("https://codeit-assets.s3.ap-northeast-2.amazonaws.com/tutorials/temp/boston.csv")
boston_df
X = boston_df.drop(columns='MEDV')
#boston_df
X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
y = boston_df[['MEDV']]
y
# Out:
#      MEDV
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %%
print(X_train.shape) 
print(X_test.shape)
print(y_train.shape) 
print(y_test.shape)
# Out:
# (404, 13)
# (102, 13)
# (404, 1)
# (102, 1)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_ #세타1,2,3,4,... 세타 값들
# Out:
# array([[-1.30799852e-01,  4.94030235e-02,  1.09535045e-03,
#          2.70536624e+00, -1.59570504e+01,  3.41397332e+00,
#          1.11887670e-03, -1.49308124e+00,  3.64422378e-01,
#         -1.31718155e-02, -9.52369666e-01,  1.17492092e-02,
#         -5.94076089e-01]])

# %%
model.intercept_ # 세타0
# Out:
# array([37.91248701])

# %%
# 모델평가
y_test_prediction = model.predict(X_test)

# %%
y_test_prediction
# Out:
# array([[37.56311787],
#        [32.14445143],
#        [27.06573629],
#        [ 5.67080633],
#        [35.09982577],
#        [ 5.85803701],
#        [27.53708506],
#        [31.81019188],
#        [26.35634771],
#        [22.77208748],
#        [31.91183048],
#        [21.50224061],
#        [23.70119983],
#        [33.3622504 ],
#        [28.51633591],
#        [14.39456899],
#        [ 0.19284025],
#        [18.66247155],
#        [13.71004139],
#        [14.13408635],
#        [ 2.03263952],
#        [19.7280831 ],
#        [38.18657429],
#        [24.19760058],
#        [31.30247973],
#        [11.14144544],
#        [25.03636951],
#        [23.27970871],
#        [22.49420127],
#        [20.52972594],
#        [15.16513744],
#        [ 6.92553586],
#        [18.3557733 ],
#        [22.37179804],
#        [28.91287973],
#        [19.02980786],
#        [30.19357214],
#        [ 8.74384915],
#        [40.86691522],
#        [34.53763591],
#        [20.70224878],
# ...

# %%
#예측값 실제 y 값 비교- 평균 제곱근 오차
mean_squared_error(y_test, y_test_prediction) 
mean_squared_error(y_test, y_test_prediction) ** 0.5 # 약 4500달러 오차 
#입력변수를 많이 써서 다중 선형회귀해서 오차가 줄어들었다.
# Out:
# 4.568292042303197

# %%
# 필요한 라이브러리 import
from sklearn import datasets
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LinearRegression
# from sklearn.metrics import mean_squared_error

# import pandas as pd  

# 당뇨병 데이터 갖고 오기
diabetes_dataset = datasets.load_diabetes()

# 입력 변수를 사용하기 편하게 pandas dataframe으로 변환
X = pd.DataFrame(diabetes_dataset.data, columns=diabetes_dataset.feature_names)

# 목표 변수를 사용하기 편하게 pandas dataframe으로 변환
y = pd.DataFrame(diabetes_dataset.target, columns=['diabetes'])

# train_test_split를 사용해서 주어진 데이터를 학습, 테스트 데이터로 나눈다
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=5)

linear_regression_model = LinearRegression()  # 선형 회귀 모델을 가지고 오고 
linear_regression_model.fit(X_train, y_train)  # 학습 데이터를 이용해서 모델을 학습 시킨다

y_test_predict = linear_regression_model.predict(X_test)  # 학습시킨 모델로 예측

# 평균 제곱 오차의 루트를 통해서 테스트 데이터에서의 모델 성능 판단
mse = mean_squared_error(y_test, y_test_predict)

mse ** 0.5
